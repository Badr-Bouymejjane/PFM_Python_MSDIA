# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('data/final_data.csv')

# %%
df.columns
# Out:
# Index(['title', 'partner', 'rating', 'reviews', 'metadata', 'link', 'category',
#        'scraped_at', 'source_domain', 'num_ratings', 'duration_hours',
#        'level_enc', 'title_clean', 'popularity_score', 'id', 'price'],
#       dtype='object')

# %%
df[df['price'].isna()]="19.99$"

# %%
df['price'].isna().sum()
# Out:
# 0

# %%
# shuffle data
df = df.sample(frac=1, random_state=42).reset_index(drop=True)

# save it
df.to_csv("data/final_courses_shuffled.csv", index=False)
